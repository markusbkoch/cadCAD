# %%
import pandas as pd
from tabulate import tabulate

from SimCAD.engine import ExecutionMode, ExecutionContext, Executor
from sandboxUX import config1, config2
from SimCAD import configs

# ToDo: pass ExecutionContext with execution method as ExecutionContext input

exec_mode = ExecutionMode()

print("Simulation Run 1")
print()
single_config = [configs[0]]
single_proc_ctx = ExecutionContext(exec_mode.single_proc)
run1 = Executor(single_proc_ctx, single_config)
run1_raw_result = run1.main()
result = pd.DataFrame(run1_raw_result)
print(tabulate(result, headers='keys', tablefmt='psql'))
print()

print("Simulation Run 2: Pairwise Execution")
print()
multi_proc_ctx = ExecutionContext(exec_mode.multi_proc)
run2 = Executor(multi_proc_ctx, configs)
run2_raw_results = run2.main()
for raw_result in run2_raw_results:
    result = pd.DataFrame(raw_result)
    print(tabulate(result, headers='keys', tablefmt='psql'))
print()
# Out:
# Simulation Run 1
#
# single_proc: [<SimCAD.Configuration object at 0x106e918d0>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-f25f28cd9767> in <module>()
#      15 single_proc_ctx = ExecutionContext(exec_mode.single_proc)
#      16 run1 = Executor(single_proc_ctx, single_config)
# ---> 17 run1_raw_result = run1.main()
#      18 result = pd.DataFrame(run1_raw_result)
#      19 print(tabulate(result, headers='keys', tablefmt='psql'))
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/__init__.py in execute(self)
#      70
#      71         if self.exec_context == ExecutionMode.single_proc:
# ---> 72             return single_proc_exec(simulation_execs, states_lists, configs_structs, env_processes_list, Ts, Ns)
#      73         elif self.exec_context == ExecutionMode.multi_proc:
#      74             if len(self.configs) > 1:
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/__init__.py in single_proc_exec(simulation_execs, states_lists, configs_structs, env_processes_list, Ts, Ns)
#      66             simulation, states_list, config = simulation_execs.pop(), states_lists.pop(), configs_structs.pop()
#      67             env_processes, T, N = env_processes_list.pop(), Ts.pop(), Ns.pop()
# ---> 68             result = simulation(states_list, config, env_processes, T, N)
#      69             return flatten(result)
#      70
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/simulation.py in simulation(self, states_list, configs, env_processes, time_seq, runs)
#      95         for run in range(runs):
#      96             run += 1
# ---> 97             head, *tail = self.pipe(states_list, configs, env_processes, time_seq, run)
#      98             head[-1]['mech_step'], head[-1]['time_step'], head[-1]['run'] = 0, 0, run
#      99             simulation_list = [head] + tail
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/simulation.py in pipe(self, states_list, configs, env_processes, time_seq, run)
#      83         simulation_list = [states_list]
#      84         for time_step in time_seq:
# ---> 85             pipe_run = self.block_gen(simulation_list[-1], configs, env_processes, time_step, run)
#      86             _, *pipe_run = pipe_run
#      87             simulation_list.append(pipe_run)
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/simulation.py in block_gen(self, states_list, configs, env_processes, t_step, run)
#      70         for config in configs:
#      71             s_conf, b_conf = config[0], config[1]
# ---> 72             states_list = self.mech_step(m_step, states_list, s_conf, b_conf, env_processes, t_step, run)
#      73             m_step += 1
#      74
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/simulation.py in mech_step(self, m_step, sL, state_funcs, behavior_funcs, env_processes, t_step, run)
#      36         last_in_obj = sL[-1]
#      37
# ---> 38         _input = self.getBehaviorInput(m_step, sL, last_in_obj, behavior_funcs)
#      39
#      40         # print(sL)
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/engine/simulation.py in getBehaviorInput(self, step, sL, s, funcs)
#      15             return list(map(lambda f: f(step, sL, s), funcs))
#      16
# ---> 17         return foldr(call, getColResults(step, sL, s, funcs))(ops)
#      18
#      19
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fn/op.py in fold(it)
#      69         args = [flip(f), reversed(it)]
#      70         if init is not None: args.append(init)
# ---> 71         return reduce(*args)
#      72
#      73     return fold
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fn/op.py in _flipper(a, b)
#      24
#      25     def _flipper(a, b):
# ---> 26         return f(b, a)
#      27
#      28     setattr(_flipper, "__flipback__", f)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fn/op.py in call(f, *args, **kwargs)
#       9
#      10 def call(f, *args, **kwargs):
# ---> 11     return f(*args, **kwargs)
#      12
#      13 def flip(f):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fn/op.py in fold(it)
#      69         args = [flip(f), reversed(it)]
#      70         if init is not None: args.append(init)
# ---> 71         return reduce(*args)
#      72
#      73     return fold
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fn/op.py in _flipper(a, b)
#      24
#      25     def _flipper(a, b):
# ---> 26         return f(b, a)
#      27
#      28     setattr(_flipper, "__flipback__", f)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/fn/func.py in _curried(*args, **kwargs)
#      79
#      80         if count == len(spec.args) - len(args):
# ---> 81             return func(*args, **kwargs)
#      82
#      83         return curried(partial(func, *args, **kwargs))
#
# ~/Documents/GitHub/DiffyQ-SimCAD/SimCAD/utils/configuration.py in dict_op(f, d1, d2)
#      86             return target_dict[key]
#      87
# ---> 88     key_set = set(list(d1.keys()) + list(d2.keys()))
#      89
#      90     return {k: f(set_base_value(d1, d2, k), set_base_value(d2, d1, k)) for k in key_set}
#
# AttributeError: 'int' object has no attribute 'keys'
